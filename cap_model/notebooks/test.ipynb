# %%
import mlflow

mlflow.set_tracking_uri("http://localhost:5000")
client = mlflow.tracking.MlflowClient()

# List all experiments
experiments = client.search_experiments()
print(f"Connected! Found {len(experiments)} experiments")
# Out:
# Connected! Found 1 experiments

# %%
from dotenv import load_dotenv
import os
from kaggle.api.kaggle_api_extended import KaggleApi

# Load env variables
load_dotenv()  # reads .env in current folder

# Check that env vars are loaded
print("Kaggle username:", os.environ.get("KAGGLE_USERNAME"))
print("Kaggle key:", "*"*5)  # don't print full key

# Authenticate
api = KaggleApi()
api.authenticate()
print("Kaggle authenticated successfully!")
# Out:
# Kaggle username: phatngo
# Kaggle key: *****
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[2], line 14
#      12 # Authenticate
#      13 api = KaggleApi()
# ---> 14 api.authenticate()
#      15 print("Kaggle authenticated successfully!")
#
# File ~/.local/lib/python3.10/site-packages/kaggle/api/kaggle_api_extended.py:434, in KaggleApi.authenticate(self)
#     432     return
#     433   else:
# --> 434     raise IOError('Could not find {}. Make sure it\'s located in'
#     435                   ' {}. Or use the environment method. See setup'
#     436                   ' instructions at'
#     437                   ' https://github.com/Kaggle/kaggle-api/'.format(
#     438                       self.config_file, self.config_dir))
#     440 # Step 3: load into configuration!
#     441 self._load_config(config_data)
#
# OSError: Could not find kaggle.json. Make sure it's located in /home/thanhphat/.config/kaggle. Or use the environment method. See setup instructions at https://github.com/Kaggle/kaggle-api/
